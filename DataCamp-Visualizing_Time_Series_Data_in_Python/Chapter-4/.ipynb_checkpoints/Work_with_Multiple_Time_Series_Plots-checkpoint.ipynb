# %% [markdown]
# #Visualizing Time Series Data in Python

# %% [markdown]
# ## Work with Multiple Time Series

# %% [markdown]
# ##Importing the required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %% [markdown]
# ##Importing & Loading the dataset

# %% [markdown]
# ### Knowing the dataset

# %% [markdown]
# The dataset contains the amount of different types of meat produced in the USA between 1944 and 2012.

# %% [markdown]
# ###Importing the dataset

# %%
path = './ch4_meat.csv'

# %% [markdown]
# ###Loading the dataset

# %%
df = pd.read_csv(path)

# %% [markdown]
# ###Data Manipulations

# %% [markdown]
# The `info()` method of pandas DataFrame displays information such as the number of rows and columns, the total memory usage, the data type of each column, and the number of non-NaN elements.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             827 non-null    object
#  1   beef             827 non-null    float64
#  2   veal             827 non-null    float64
#  3   pork             827 non-null    float64
#  4   lamb_and_mutton  827 non-null    float64
#  5   broilers         635 non-null    float64
#  6   other_chicken    143 non-null    float64
#  7   turkey           635 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 51.8+ KB

# %% [markdown]
# Converting the dtype of datestamp column in the dataframe

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# Setting the datestamp column as the index of the dataframe

# %%
df = df.set_index('date')

# %% [markdown]
# Rechecking the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 827 entries, 1944-01-01 to 2012-11-01
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   beef             827 non-null    float64
#  1   veal             827 non-null    float64
#  2   pork             827 non-null    float64
#  3   lamb_and_mutton  827 non-null    float64
#  4   broilers         635 non-null    float64
#  5   other_chicken    143 non-null    float64
#  6   turkey           635 non-null    float64
# dtypes: float64(7)
# memory usage: 51.7 KB

# %% [markdown]
# `df.head()` - Displays the first 5 rows of the dataframe

# %%
df.head()
# Out:
#              beef   veal    pork  lamb_and_mutton  broilers  other_chicken  \
# date
# 1944-01-01  751.0   85.0  1280.0             89.0       NaN            NaN
# 1944-02-01  713.0   77.0  1169.0             72.0       NaN            NaN
# 1944-03-01  741.0   90.0  1128.0             75.0       NaN            NaN
# 1944-04-01  650.0   89.0   978.0             66.0       NaN            NaN
# 1944-05-01  681.0  106.0  1029.0             78.0       NaN            NaN
#
#             turkey
# date
# 1944-01-01     NaN
# 1944-02-01     NaN
# 1944-03-01     NaN
# 1944-04-01     NaN
# 1944-05-01     NaN

# %% [markdown]
# The `describe()` method is used for calculating some statistical data like percentile, mean and std of the numerical values of the dataframe.

# %%
df.describe()
# Out:
#               beef        veal  ...  other_chicken      turkey
# count   827.000000  827.000000  ...     143.000000  635.000000
# mean   1683.463362   54.198549  ...      43.033566  292.814646
# std     501.698480   39.062804  ...       3.867141  162.482638
# min     366.000000    8.800000  ...      32.300000   12.400000
# 25%    1231.500000   24.000000  ...      40.200000  154.150000
# 50%    1853.000000   40.000000  ...      43.400000  278.300000
# 75%    2070.000000   79.000000  ...      45.650000  449.150000
# max    2512.000000  215.000000  ...      51.100000  585.100000
#
# [8 rows x 7 columns]

# %% [markdown]
# ##Plotting the data

# %% [markdown]
# ###Basic Line Chart

# %%
df.plot(figsize=(12,6))  #generates the line plot
plt.xlabel('Date')  #sets xlabel
plt.show()  #shows plot

# %% [markdown]
# ###Area Chart

# %% [markdown]
# Area charts are commonly used when dealing with multiple time series, and can be leveraged to represent cumulated totals. With the pandas library, we can simply leverage the `.plot.area()` method to produce an area chart.

# %%
df.plot.area(figsize=(12,6))  #generates area plot
plt.xlabel('Date')  #sets xlabel
plt.title('Area Chart')  #sets title
plt.show()  #shows plot

# %% [markdown]
# ##Enhacing plots
#
# Plotting and visualizing data that contains multiple time series can be a challenging task. While the pandas library can still be leveraged to perform this task, there are a number of parameters that can be applied in order to optimize the readability of the graphs.
#
# Now, we will discuss how multiple times series can be clearly displayed simultaneously in Python.

# %% [markdown]
# ### Clarity is Key
# When plotting multiple time series, matplotlib will iterate through its default color scheme until all columns in the DataFrame have been plotted. Therefore, the repetition of the default colors may make it difficult to distinguish some of the time series.

# %% [markdown]
# ###Colormap Argument
# To remedy this, the `.plot()` method has an additional argument called `colormap`.This argument allows us to assign a wide range of color palettes with varying contrasts and intensities. We can either define our own Matplotlib colormap, or use a string that matches a colormap registered with matplotlib.

# %% [markdown]
# Changing line colors with the color map argument.
#
# In this example, I have used the `PuOr` color palette.

# %%
df.plot(colormap='PuOr', figsize=(12, 5))
plt.show()

# %% [markdown]
# In this example, I have used the `terrain` color palette.

# %%
df.plot(colormap='terrain', figsize=(12,5))
plt.show()

# %% [markdown]
# In this example, I have used the `gist_ncar` color palette.

# %%
df.plot.area(colormap='gist_ncar', figsize=(12,5))
plt.show()

# %% [markdown]
# ###Adding Information to plots
#
# Adding statistical summaries to the plot

# %%
df.plot(figsize=(12, 6))

plt.table(cellText=df.describe().values,
          colWidths=[0.3]*len(df.columns),
          rowLabels=df.describe().index,
          colLabels=df.describe().columns,
          loc='top')
plt.show()

# %% [markdown]
# ###Facet Plots
# In order to overcome issues with visualizing datasets containing time series of different scales, we can leverage the `subplots` argument, which will plot each column of a DataFrame on a different subplot. In addition, the layout of our subplots can be specified using the `layout` keyword, which accepts two integers specifying the number of rows and columns to use. It is important to ensure that the total number of subplots is greater than or equal to the number of time series in our DataFrame. We can also specify if each subgraph should share the values of their x-axis and y-axis using the `sharex` and `sharey` arguments. Finally, we need to specify the total size of our graph (which will contain all subgraphs) using the `figsize` argument.

# %%
df.plot(subplots=True, #to plot different plots for each column
          layout=(4, 2), #to specify number of rows and columns for the layout of subplots
          sharex=False,  #to share values on x-axis
          sharey=False,   #to sgare values on y-axis
          colormap='Dark2',   #sets the colormap 
          legend=True,  #shows the labels on each plot
          linewidth=0.5,  #specifies the width of the line in the subplots
          figsize=(10,10))  #specifies the total size of our graph

plt.show()  #shows plot

# %% [markdown]
# ##Correlation b/w variables

# %% [markdown]
# One of the most widely used methods to assess the similarities between a group of time series is by using the correlation coefficient. The correlation coefficient is a measure used to determine the strength or lack of relationship between two variables. The standard way to compute correlation coefficients is by using the Pearson's coefficient, which should be used when we think that the relationship between the variables of interest is linear. Otherwise, we can use the Kendall Tau or Spearman rank coefficient methods when the relationship between the variables of interest is thought to be non-linear.

# %% [markdown]
# ### Compute correlations
# In Python, we can quickly compute the correlation coefficient between two variables by using the pearsonr, spearmanr or kendalltau functions in the `scipy.stats` module. All three of these correlation measures return both the correlation and p-value between the two variables.

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau

# %%
a = df['beef']
b = df['pork']

# %% [markdown]
# Pearson Coefficient

# %%
result = pearsonr(a, b)
print('Pearson Correlation')
print('Correlation =',result[0], ', p-value =',result[1])
# Out:
# Pearson Correlation
# Correlation = 0.7870466291322202 , p-value = 2.955802934147619e-175

# %% [markdown]
# Spearman Coefficient

# %%
result = spearmanr(a, b)
print('Spearman Correlation')
print('Correlation =',result[0], ', p-value =',result[1])
# Out:
# Spearman Correlation
# Correlation = 0.8275872847134006 , p-value = 4.316054119444063e-209

# %% [markdown]
# Kendall Tau Coefficient

# %%
result = kendalltau(a, b)
print('Kendalltau Correlation')
print('Correlation =',result[0], ', p-value =',result[1])
# Out:
# Kendalltau Correlation
# Correlation = 0.6302055718249879 , p-value = 7.341078875247838e-162

# %% [markdown]
# ###Correlation Matrix
# If we want to investigate the dependence between multiple variables at the same time, we will need to compute a correlation matrix.
#
# The result is a table containing the correlation coefficients between each pair of variables. Correlation coefficients can take any values between -1 and 1. A correlation of 0 indicates no correlation, while 1 and -1 indicate strong positive and negative correlation.
#
# Importantly, a correlation matrix will be always be "symmetric", i.e., the correlation between x and y will be identical to the correlation between y and x. Finally, the diagonal values will always be equal to 1, since the correlation between the variable x and a copy of itself is 1.

# %% [markdown]
# ###Computing Correlation Matrix with pandas
#
# The pandas library comes in with a `corr()` method that allows to measure the correlation between all pairs of columns in a DataFrame.
#
# Using the meat dataset, we selected the columns beef , veal and turkey and invoked the `corr()` method by invoking both the `pearson` and `spearman` methods. The results are correlation matrices stored as two new pandas DataFrames called `corr_p` and `corr_s`.

# %%
corr_p = df[['beef','turkey','veal']].corr(method='pearson')
corr_p
# Out:
#             beef    turkey      veal
# beef    1.000000  0.738070 -0.829704
# turkey  0.738070  1.000000 -0.768366
# veal   -0.829704 -0.768366  1.000000

# %%
corr_s = df[['beef','turkey','veal']].corr(method='spearman')
corr_s
# Out:
#             beef    turkey      veal
# beef    1.000000  0.778533 -0.812437
# turkey  0.778533  1.000000 -0.829492
# veal   -0.812437 -0.829492  1.000000

# %%
corr_mat = df.corr('pearson')

# %% [markdown]
# ###Heat Maps
# Once we have stored our correlation matrix in a new DataFrame (`corr_mat`), it might be easier to visualize it instead of trying to interpret several correlation coefficients at once.
#
# In order to achieve this, we will introduce the Seaborn library, which will be used to produce a heatmap of our correlation matrix. Here we use the `heatmap()` function on the object `corr_mat`.

# %%
sns.heatmap(corr_mat)  #generates heat map
plt.show()  #shows plot

# %%
sns.heatmap(corr_mat, annot=True)  #generates heat map
plt.show()  #shows plot

# %% [markdown]
# ###Cluster Maps
#
# Heatmap is a useful tool to visualize correlation matrices, but the lack of ordering can make it difficult to read, or even identify which groups of time series are the most similar.
#
# For this reason, it is recommended to leverage the `clustermap()` function in the seaborn library, which applies hierarchical clustering to our correlation matrix to plot a sorted heatmap, where similar time series are placed closer to one another.

# %%
sns.clustermap(corr_mat)  #generates cluster map
plt.show()  #shows plot

# %%
sns.clustermap(corr_mat, annot=True)  #generates cluster map
plt.show()  #shows plot

# %% [markdown]
# ## Conclusion
# In the field of Data Science, it is common to work with multiple time series simultaneously.
#
# In this jupyter notebook, we learnt how to plot multiple time series at once, and how to discover and describe relationships between multiple time series.
